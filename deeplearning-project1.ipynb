# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/student-grades-intermediate-dataset/Student_Grades.csv

# %%
df=pd.read_csv("/kaggle/input/student-grades-intermediate-dataset/Student_Grades.csv")
df.head(3)
# Out:
#    Hours  Practice  TeamWork  MidTerm  FinalExam  Scores Grade
# 0    2.5       0.5       0.0        2        2.3      21     C
# 1    5.1       1.5       0.5        4        4.9      47     B
# 2    3.2       1.0       0.5        3        2.9      27     C

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
y=df["Scores"]
x=df.drop(columns=["Scores","Grade"])

y=y.values.astype("float32")
x=x.values.astype("float32")

# %%
model=Sequential()
model.add(Dense(16))
model.add(Dense(32,activation="relu"))
model.add(Dense(32,activation="relu"))
model.add(Dense(1))
model.compile(optimizer='adam',loss='mse')
model.fit(x,y,epochs=128,batch_size=16)
# Out:
# Epoch 1/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 3026.4338
# Epoch 2/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3269.4888
# Epoch 3/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3032.1040
# Epoch 4/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3082.3403
# Epoch 5/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2910.6533
# Epoch 6/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2913.7957
# Epoch 7/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2954.2146
# Epoch 8/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2776.2437
# Epoch 9/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2817.5007
# Epoch 10/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2753.4946
# Epoch 11/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2441.3882
# Epoch 12/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2656.8657
# Epoch 13/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2540.6306
# Epoch 14/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2550.1648
# Epoch 15/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2573.8118
# Epoch 16/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2473.5388
# Epoch 17/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2388.8704
# Epoch 18/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2426.3008
# Epoch 19/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2142.5376
# Epoch 20/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2004.7572
# Epoch 21/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2160.5442
# Epoch 22/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1889.2017
# Epoch 23/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1807.1204
# Epoch 24/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1707.4510
# Epoch 25/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1736.5035
# Epoch 26/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1667.9846
# Epoch 27/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1489.8375
# Epoch 28/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1270.7662
# Epoch 29/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1239.6764
# Epoch 30/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1175.0967
# Epoch 31/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1106.2313
# Epoch 32/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 967.3953
# Epoch 33/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 882.0594
# Epoch 34/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 769.6531
# Epoch 35/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 698.4614
# Epoch 36/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 603.5411
# Epoch 37/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 471.6390
# Epoch 38/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 392.2004
# Epoch 39/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 316.3996
# Epoch 40/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 239.2323
# Epoch 41/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 186.1356
# Epoch 42/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 117.3677
# Epoch 43/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 75.6226
# Epoch 44/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 52.9681
# Epoch 45/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 29.0218
# Epoch 46/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 14.3535
# Epoch 47/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.9077
# Epoch 48/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.6172
# Epoch 49/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 10.8277
# Epoch 50/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 12.7968
# Epoch 51/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 18.9192
# Epoch 52/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.6742
# Epoch 53/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 22.6978
# Epoch 54/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 22.2451
# Epoch 55/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 16.4944
# Epoch 56/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 20.2127
# Epoch 57/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 15.8756
# Epoch 58/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 12.3498
# Epoch 59/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 12.6052
# Epoch 60/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 10.2347
# Epoch 61/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.2169
# Epoch 62/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.6476
# Epoch 63/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.0609
# Epoch 64/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.2030
# Epoch 65/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.2886
# Epoch 66/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.0895
# Epoch 67/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.7970
# Epoch 68/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.3661
# Epoch 69/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.6537
# Epoch 70/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.2061
# Epoch 71/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.2893
# Epoch 72/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.8385
# Epoch 73/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.5699
# Epoch 74/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.2655
# Epoch 75/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.4389
# Epoch 76/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.9589
# Epoch 77/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.7313
# Epoch 78/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.3244
# Epoch 79/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.5044
# Epoch 80/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.4515
# Epoch 81/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1563
# Epoch 82/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.4052
# Epoch 83/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0715
# Epoch 84/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6557
# Epoch 85/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.2260
# Epoch 86/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.6365
# Epoch 87/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.5777
# Epoch 88/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.3429
# Epoch 89/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6183
# Epoch 90/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.2020
# Epoch 91/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.6411
# Epoch 92/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5625
# Epoch 93/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.4796
# Epoch 94/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.6797
# Epoch 95/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.1600
# Epoch 96/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.1035
# Epoch 97/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.3198
# Epoch 98/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.3181
# Epoch 99/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3319
# Epoch 100/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.7922
# Epoch 101/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.5192
# Epoch 102/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7754
# Epoch 103/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.8065
# Epoch 104/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.2625
# Epoch 105/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9677
# Epoch 106/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7913
# Epoch 107/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1936
# Epoch 108/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.4041
# Epoch 109/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1557
# Epoch 110/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3563
# Epoch 111/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.8863
# Epoch 112/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.2192
# Epoch 113/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.7987
# Epoch 114/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3858
# Epoch 115/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.8467
# Epoch 116/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5502
# Epoch 117/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.3771
# Epoch 118/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.0396
# Epoch 119/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7679
# Epoch 120/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6133
# Epoch 121/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1108
# Epoch 122/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7945
# Epoch 123/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.1034
# Epoch 124/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1506
# Epoch 125/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.4215
# Epoch 126/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3107
# Epoch 127/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.7510
# Epoch 128/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.0960

# %%
df.head(3)
# Out:
#    Hours  Practice  TeamWork  MidTerm  FinalExam  Scores Grade
# 0    2.5       0.5       0.0        2        2.3      21     C
# 1    5.1       1.5       0.5        4        4.9      47     B
# 2    3.2       1.0       0.5        3        2.9      27     C

# %%
model.predict(np.array([[13,1,1,2,3.3]]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# array([[35.246452]], dtype=float32)
